# %% [markdown]
# <a href="https://colab.research.google.com/github/alanashly22/first/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
age=[23,22,24,25,26]
mySeries= pd.Series(age)
mySeries
# Out:
# 0    23
# 1    22
# 2    24
# 3    25
# 4    26
# dtype: int64

# %%
age=[23,22,24,25,26]
mySeries= pd.Series(age,index=["a","b","c","d","e"])
mySeries
# Out:
# a    23
# b    22
# c    24
# d    25
# e    26
# dtype: int64

# %%
mySeries['a']
# Out:
# 23

# %%
data={'a':100,'b':200,'c':300}
mySeries=pd.Series(data)
mySeries
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %%
mySeries.values
# Out:
# array([100, 200, 300])

# %%
mySeries.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
mySeries[['a','b']]
# Out:
# a    100
# b    200
# dtype: int64

# %%
mySeries>200
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
mySeries[mySeries>100]
# Out:
# b    200
# c    300
# dtype: int64

# %%
mySeries.min()
# Out:
# 100

# %%
mySeries.max()
# Out:
# 300

# %%
mySeries*3
# Out:
# a    300
# b    600
# c    900
# dtype: int64

# %%
mySeries[(mySeries>100)&(mySeries<300)]
# Out:
# b    200
# dtype: int64

# %%
data ={'kerala':28,'andhra':25,'TN':38,"karnataka":19,'delhi':38}
mySeries=pd.Series(data)
mySeries
# Out:
# kerala       28
# andhra       25
# TN           38
# karnataka    19
# delhi        38
# dtype: int64

# %%
states=['andhra','delhi','TN','MP','kerala','karnataka']
mySeries2=pd.Series(mySeries,states)
mySeries2
# Out:
# andhra       25.0
# delhi        38.0
# TN           38.0
# MP            NaN
# kerala       28.0
# karnataka    19.0
# dtype: float64

# %%
mySeries2.isna()
# Out:
# andhra       False
# delhi        False
# TN           False
# MP            True
# kerala       False
# karnataka    False
# dtype: bool

# %%
mySeries2.isnull()
# Out:
# andhra       False
# delhi        False
# TN           False
# MP            True
# kerala       False
# karnataka    False
# dtype: bool

# %%
mySeries2['kerala']
# Out:
# 28.0

# %%
mySeries2.loc['kerala']
# Out:
# 28.0

# %%
mySeries2.iloc[4]
# Out:
# 28.0

# %%
mySeries2.iloc[1:4]
# Out:
# delhi    38.0
# TN       38.0
# MP        NaN
# dtype: float64

# %%
mySeries2
# Out:
# andhra       25.0
# delhi        38.0
# TN           38.0
# MP            NaN
# kerala       28.0
# karnataka    19.0
# dtype: float64

# %%
mySeries2.head(3)
# Out:
# andhra    25.0
# delhi     38.0
# TN        38.0
# dtype: float64

# %%
mySeries2.tail(3)
# Out:
# MP            NaN
# kerala       28.0
# karnataka    19.0
# dtype: float64

# %%
mySeries2.sample(2)
# Out:
# andhra    25.0
# MP         NaN
# dtype: float64

# %% [markdown]
# # **panadas-dataframes**

# %%
names=["Alice","Bob","Charlie","David","Eve"]
age=[25,30,35,40,45]
salary=[60000,50000,70000,80000,90000]
profession=["Engineer","Teacher","Doctor","Artist","Lawyer"]

# %%
data=pd.DataFrame({"Names":names,"Age":age,"Salary":salary,"Profession":profession})
data
# Out:
#      Names  Age  Salary Profession
# 0    Alice   25   60000   Engineer
# 1      Bob   30   50000    Teacher
# 2  Charlie   35   70000     Doctor
# 3    David   40   80000     Artist
# 4      Eve   45   90000     Lawyer

# %%
data2=pd.DataFrame(data,columns=["Names","Profession","Salary","Age","Department"])
data2
# Out:
#      Names Profession  Salary  Age  Department
# 0    Alice   Engineer   60000   25         NaN
# 1      Bob    Teacher   50000   30         NaN
# 2  Charlie     Doctor   70000   35         NaN
# 3    David     Artist   80000   40         NaN
# 4      Eve     Lawyer   90000   45         NaN

# %%
data.rename(columns={"Profession":"Job_Title"},inplace=True)

# %%
data
# Out:
#      Names  Age  Salary Job_Title
# 0    Alice   25   60000  Engineer
# 1      Bob   30   50000   Teacher
# 2  Charlie   35   70000    Doctor
# 3    David   40   80000    Artist
# 4      Eve   45   90000    Lawyer

# %%
data.rename(columns={"Names":"Name","Salary":"Salary per year"},inplace=True)

# %%
data
# Out:
#       Name  Age  Salary per year Job_Title
# 0    Alice   25            60000  Engineer
# 1      Bob   30            50000   Teacher
# 2  Charlie   35            70000    Doctor
# 3    David   40            80000    Artist
# 4      Eve   45            90000    Lawyer

# %%
data.iloc[1:4]
# Out:
#       Name  Age  Salary per year Job_Title
# 1      Bob   30            50000   Teacher
# 2  Charlie   35            70000    Doctor
# 3    David   40            80000    Artist

# %%
data.set_index("Name",inplace=True)
data
# Out:
#          Age  Salary per year Job_Title
# Name
# Alice     25            60000  Engineer
# Bob       30            50000   Teacher
# Charlie   35            70000    Doctor
# David     40            80000    Artist
# Eve       45            90000    Lawyer

# %%
data['city']=["chennai","banglore","hyderabad","pune","mumbai"]
data
# Out:
#          Age  Salary per year Job_Title       city
# Name
# Alice     25            60000  Engineer    chennai
# Bob       30            50000   Teacher   banglore
# Charlie   35            70000    Doctor  hyderabad
# David     40            80000    Artist       pune
# Eve       45            90000    Lawyer     mumbai

# %%
data['savings']=data['Salary per year']/10
data
# Out:
#          Age  Salary per year Job_Title       city  savings
# Name
# Alice     25            60000  Engineer    chennai   6000.0
# Bob       30            50000   Teacher   banglore   5000.0
# Charlie   35            70000    Doctor  hyderabad   7000.0
# David     40            80000    Artist       pune   8000.0
# Eve       45            90000    Lawyer     mumbai   9000.0

# %%
data=data.assign(Bonus=data['Salary per year']*0.1,tax=data['Salary per year']*0.5,fav_color=["orange","red","blue","green","yellow"])
data
# Out:
#          Age  Salary per year Job_Title       city  savings   Bonus      tax  \
# Name
# Alice     25            60000  Engineer    chennai   6000.0  6000.0  30000.0
# Bob       30            50000   Teacher   banglore   5000.0  5000.0  25000.0
# Charlie   35            70000    Doctor  hyderabad   7000.0  7000.0  35000.0
# David     40            80000    Artist       pune   8000.0  8000.0  40000.0
# Eve       45            90000    Lawyer     mumbai   9000.0  9000.0  45000.0
#
#         fav_color
# Name
# Alice      orange
# Bob           red
# Charlie      blue
# David       green
# Eve        yellow

# %%
del data['savings']
data
# Out:
#          Age  Salary per year Job_Title       city   Bonus      tax fav_color
# Name
# Alice     25            60000  Engineer    chennai  6000.0  30000.0    orange
# Bob       30            50000   Teacher   banglore  5000.0  25000.0       red
# Charlie   35            70000    Doctor  hyderabad  7000.0  35000.0      blue
# David     40            80000    Artist       pune  8000.0  40000.0     green
# Eve       45            90000    Lawyer     mumbai  9000.0  45000.0    yellow

# %%
data.drop(columns=['Age','Salary'])
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-56ae6511cffb> in <cell line: 1>()
# ----> 1 data.drop(columns=['Age','Salary'])
#       2 data
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
data
# Out:
#          Age  Salary per year Job_Title       city   Bonus      tax fav_color
# Name
# Alice     25            60000  Engineer    chennai  6000.0  30000.0    orange
# Bob       30            50000   Teacher   banglore  5000.0  25000.0       red
# Charlie   35            70000    Doctor  hyderabad  7000.0  35000.0      blue
# David     40            80000    Artist       pune  8000.0  40000.0     green
# Eve       45            90000    Lawyer     mumbai  9000.0  45000.0    yellow

# %%
data.nunique()
# Out:
# Age                5
# Salary per year    5
# Job_Title          5
# city               5
# Bonus              5
# tax                5
# fav_color          5
# dtype: int64

# %%
data['Job_Title'].nunique()
# Out:
# 5

# %%
data['Job_Title'].value_counts()
# Out:
# Job_Title
# Engineer    1
# Teacher     1
# Doctor      1
# Artist      1
# Lawyer      1
# Name: count, dtype: int64

# %%
data.duplicated()
# Out:
# Name
# Alice      False
# Bob        False
# Charlie    False
# David      False
# Eve        False
# dtype: bool

# %%
raw_data = {"first_name": ["Jason", "Jason", "Jason","Tina", "Jake", "Amy"],
            "last_name": ["Miller", "Miller", "Miller","Ali", "Milner", "Cooze"],
            "age": [42, 42, 1111111, 36, 24, 73],
            "preTestScore": [4, 4, 4, 31, 2, 3],
            "postTestScore": [25, 25, 25, 57, 62, 70]}

df = pd.DataFrame(raw_data, columns = ["first_name", "last_name", "age",
                                        "preTestScore", "postTestScore"])
print(df)
# Out:
#   first_name last_name      age  preTestScore  postTestScore
# 0      Jason    Miller       42             4             25
# 1      Jason    Miller       42             4             25
# 2      Jason    Miller  1111111             4             25
# 3       Tina       Ali       36            31             57
# 4       Jake    Milner       24             2             62
# 5        Amy     Cooze       73             3             70

# %%
df.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df.drop_duplicates(keep="first")
# Out:
#   first_name last_name      age  preTestScore  postTestScore
# 0      Jason    Miller       42             4             25
# 2      Jason    Miller  1111111             4             25
# 3       Tina       Ali       36            31             57
# 4       Jake    Milner       24             2             62
# 5        Amy     Cooze       73             3             70

# %%
df
# Out:
#   first_name last_name      age  preTestScore  postTestScore
# 0      Jason    Miller       42             4             25
# 1      Jason    Miller       42             4             25
# 2      Jason    Miller  1111111             4             25
# 3       Tina       Ali       36            31             57
# 4       Jake    Milner       24             2             62
# 5        Amy     Cooze       73             3             70

# %%
df.drop_duplicates(['first_name'],keep="last")
# Out:
#   first_name last_name      age  preTestScore  postTestScore
# 2      Jason    Miller  1111111             4             25
# 3       Tina       Ali       36            31             57
# 4       Jake    Milner       24             2             62
# 5        Amy     Cooze       73             3             70

# %%
df
# Out:
#   first_name last_name      age  preTestScore  postTestScore
# 0      Jason    Miller       42             4             25
# 1      Jason    Miller       42             4             25
# 2      Jason    Miller  1111111             4             25
# 3       Tina       Ali       36            31             57
# 4       Jake    Milner       24             2             62
# 5        Amy     Cooze       73             3             70

# %%
df['postTestScore'].max()
# Out:
# 70

# %%
df['postTestScore'].min()
# Out:
# 25

# %%
df['postTestScore'].idxmax()
# Out:
# 5

# %%
df.iloc[df['postTestScore'].idxmax()]
# Out:
# first_name         Amy
# last_name        Cooze
# age                 73
# preTestScore         3
# postTestScore       70
# Name: 5, dtype: object

# %%
df.iloc[df['postTestScore'].idxmin()]
# Out:
# first_name        Jason
# last_name        Miller
# age                  42
# preTestScore          4
# postTestScore        25
# Name: 0, dtype: object

# %%
df.sort_values(by="first_name")
# Out:
#   first_name last_name      age  preTestScore  postTestScore
# 5        Amy     Cooze       73             3             70
# 4       Jake    Milner       24             2             62
# 0      Jason    Miller       42             4             25
# 1      Jason    Miller       42             4             25
# 2      Jason    Miller  1111111             4             25
# 3       Tina       Ali       36            31             57

# %%
df.sort_values(by="first_name",ascending=False)
# Out:
#   first_name last_name      age  preTestScore  postTestScore
# 3       Tina       Ali       36            31             57
# 0      Jason    Miller       42             4             25
# 1      Jason    Miller       42             4             25
# 2      Jason    Miller  1111111             4             25
# 4       Jake    Milner       24             2             62
# 5        Amy     Cooze       73             3             70

# %%
df.sort_values(by=["first_name","age"],ascending=False)
# Out:
#   first_name last_name      age  preTestScore  postTestScore
# 3       Tina       Ali       36            31             57
# 2      Jason    Miller  1111111             4             25
# 0      Jason    Miller       42             4             25
# 1      Jason    Miller       42             4             25
# 4       Jake    Milner       24             2             62
# 5        Amy     Cooze       73             3             70

# %%
df[(df['postTestScore']>40) & (df['age']>30)]
# Out:
#   first_name last_name  age  preTestScore  postTestScore
# 3       Tina       Ali   36            31             57
# 5        Amy     Cooze   73             3             70

# %%
df1 = df[(df["postTestScore"]>40) & (df["age"]>30)]
df1
# Out:
#   first_name last_name  age  preTestScore  postTestScore
# 3       Tina       Ali   36            31             57
# 5        Amy     Cooze   73             3             70

# %%
df1.to_csv('filter_data.csv',index=False)
df1.to_excel('filter_data.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1110                 try:
# -> 1111                     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1112                     if engine == "auto":
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     260     def __call__(self, *args, **kwds) -> T:
# --> 261         return self.__func__(*args, **kwds)
#     262
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in _get_option(pat, silent)
#     134 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 135     key = _get_single_key(pat, silent)
#     136
#
# ...

# %%
df['Position'] = df['postTestScore'].rank(ascending=False)
df
# Out:
#   first_name last_name      age  preTestScore  postTestScore  Position
# 0      Jason    Miller       42             4             25       5.0
# 1      Jason    Miller       42             4             25       5.0
# 2      Jason    Miller  1111111             4             25       5.0
# 3       Tina       Ali       36            31             57       3.0
# 4       Jake    Milner       24             2             62       2.0
# 5        Amy     Cooze       73             3             70       1.0
